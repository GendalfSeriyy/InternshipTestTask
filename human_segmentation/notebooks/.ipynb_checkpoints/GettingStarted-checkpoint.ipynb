# %%
import os
os.chdir("..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import cv2

from glob import glob

from lib import *

# %matplotlib inline

# %% [markdown]
# # Задача

# %% [markdown]
# **Требуется:** предложить модель, сегментирующую человека на фотографии.
#
# **Вход:** фотография 320x240x3.
# **Выход:** маска человека 320x240.
# **Метрика:** [Dice coefficient](https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient).
#
#
# Данные представляют из себя набор фотографий человека и маски, определяющей положение человека на фотографии.
# Доступные данные разделены на несколько папок:
# - `train` содержит фотографии 320x240x3;
# - `train_mask` содержит маски для фотографий из `train` 320x240;
# - `valid` содержит фотографии 320x240x3;
# - `valid_mask` содержит маски для фотографий из `valid` 320x240;
# - `test` содержит фотографии 320x240x3.
#
# Для лучшей модели требуется создать 2 файла, которые необходимы для валидации Вашего решения:
# - сохраненные маски для картинок из `valid` в формате `pred_valid_template.csv`;
# - html страницу с предсказанием модели для всех картинок из `test` и папку с используемыми картинками в этой html странице.
#
# Также необходимо:
# - подготовить код для проверки (докстринги, PEP8);
# - создать отчет (можно прямо в ноутбуке) с описанием Вашего исследования, гипотез и т.п.
#
# Примеры приведены ниже.

# %% [markdown]
# ---

# %% [markdown]
# # Данные, метрики и доступные функции

# %% [markdown]
# Посмотрим на данные:

# %%
path = "C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/train"
images = os.listdir(path)
ind = np.random.choice(images).split(".")[0]

img = np.array(Image.open(f"{path}/{ind}.jpg"))
mask = np.array(Image.open(f"{path}_mask/{ind}.png"))
show_img_with_mask(img, mask)

# %% [markdown]
# Пример подсчета метрики:

# %%
random_mask = np.random.randint(low=0, high=2, size=mask.shape)
show_img_with_mask(random_mask, mask)
get_dice(mask, random_mask)
# Out:
# 0.5356496825339009

# %% [markdown]
# Можно для последовательности масок вычислить среднее значение метрики:

# %%
random_masks_1 = [np.random.randint(low=0, high=2, size=mask.shape) for i in range(10)]
random_masks_2 = [np.random.randint(low=0, high=2, size=mask.shape) for i in range(10)]
get_dice(random_masks_1, random_masks_2)
# Out:
# 0.4997481193314067

# %% [markdown]
# Пример использования функций `encode_rle` и `decode_rle`:
# 1. Функция `encode_rle` используется для кодирования маски в строку для последующей записи в файл;
# 2. Функция `decode_rle` используется для восстановления маски по закодированной строке.

# %%
rle_mask = encode_rle(mask)
rle_mask
# Out:
# '4939 10 5175 18 5411 3 5415 21 5650 30 5888 35 6125 39 6362 44 6602 46 6841 50 7080 52 7133 1 7317 57 7556 59 7795 62 8035 64 8273 67 8513 68 8752 70 8990 72 9230 73 9469 75 9708 76 9947 77 10187 78 10426 80 10665 81 10905 81 11144 83 11384 83 11623 85 11863 85 12103 86 12342 87 12582 88 12822 88 13062 89 13301 90 13541 90 13781 90 14021 90 14261 90 14501 90 14741 90 14981 91 15220 92 15460 92 15700 91 15940 91 16180 91 16420 91 16660 91 16900 91 17140 90 17380 90 17620 90 17860 89 18100 89 18341 88 18581 87 18821 87 19061 87 19301 86 19542 85 19782 86 20021 89 20260 91 20499 92 20739 92 20979 91 21220 90 21460 90 
:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid")
pat3="C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid"
im_path3=sorted([(f"{pat3}/{x}") for x in listd3])
listd4=os.listdir("C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid_mask")
pat4="C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid_mask"
mas_path4=sorted([(f"{pat4}/{x}") for x in listd4])
dic_v={}
for i in range(len(mas_path4)):
    mask = np.array(Image.open(mas_path4[i]))
    rle_mask = encode_rle(mask)
    dic_v[im_path3[i]]=rle_mask

# %%
dfv=pd.DataFrame.from_dict(dic_v, orient='index')
dfv = dfv.reset_index()
dfv.head()
# Out:
#                                                index  \
# 0  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 1  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 2  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 3  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 4  C:/Users/gendalf/Documents/GitHub/InternshipTe...
#
#                                                    0
# 0  68 118 307 120 545 123 784 125 1023 126 1262 1...
# 1  8036 1 8052 1 8274 3 8284 3 8288 9 8512 4 8521...
# 2  8759 4 8999 6 9011 1 9222 2 9225 1 9238 10 924...
# 3  10967 5 11204 9 11443 11 11682 12 11710 8 1192...
# 4  24554 32 24791 40 25029 45 25267 50 25506 54 2...

# %%
dfv.columns = ['img', 'mask']
dfv.head()
# Out:
#                                                  img  \
# 0  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 1  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 2  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 3  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 4  C:/Users/gendalf/Documents/GitHub/InternshipTe...
#
#                                                 mask
# 0  68 118 307 120 545 123 784 125 1023 126 1262 1...
# 1  8036 1 8052 1 8274 3 8284 3 8288 9 8512 4 8521...
# 2  8759 4 8999 6 9011 1 9222 2 9225 1 9238 10 924...
# 3  10967 5 11204 9 11443 11 11682 12 11710 8 1192...
# 4  24554 32 24791 40 25029 45 25267 50 25506 54 2...

# %%
dft = pd.DataFrame.from_dict(dic, orient='index')
dft = dft.reset_index()
dft.columns = ['img', 'mask']

# %%
dft.head(10)
# Out:
#                                                  img  \
# 0  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 1  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 2  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 3  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 4  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 5  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 6  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 7  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 8  C:/Users/gendalf/Documents/GitHub/InternshipTe...
# 9  C:/Users/gendalf/Documents/GitHub/InternshipTe...
#
#                                                 mask
# 0  7791 3 8028 13 8265 20 8502 28 8740 32 8979 35...
# 1  8275 3 8282 1 8512 17 8744 32 8984 39 9215 49 ...
# 2  1314 2 1554 9 1793 4 1802 1 2000 4 2005 1 2037...
# 3  10196 8 10431 18 10668 25 10907 28 11145 32 11...
# 4  4190 6 4425 14 4663 20 4902 22 5140 26 5379 28...
# 5  11168 5 11406 7 11873 1 12111 1 12351 1 12591 ...
# 6  110 30 350 33 384 2 388 2 591 35 627 2 632 1 8...
# 7  5869 1 6102 1 6106 4 6111 4 6117 3 6121 3 6341...
# 8  123 3 128 2 138 1 360 11 376 4 383 3 568 2 572...
# 9  13553 10 13787 20 14022 28 14259 34 14496 40 1...

# %%
img_name, mask_rle = dft.iloc[0]
img = np.array(Image.open(img_name))
mask = decode_rle(mask_rle)
print(mask.shape)
# Out:
# (320, 240)

# %%
show_img_with_mask(img, mask)

# %%
def keras_generator(gen_df, batch_size):
    while True:
        x_batch = []
        y_batch = []
        
        for i in range(batch_size):
            img_name, mask_rle = gen_df.sample(1).values[0]
            img = np.array(Image.open(img_name))
            mask = decode_rle(mask_rle)
            
            img = cv2.resize(img, (256, 256))
            mask = cv2.resize(mask, (256, 256))
            
            
            x_batch += [img]
            y_batch += [mask]

        x_batch = np.array(x_batch) / 255.
        y_batch = np.array(y_batch)

        yield x_batch, np.expand_dims(y_batch, -1)

# %%
for x, y in keras_generator(dft, 16):
    print(y[0,:,:,0].shape)
    show_img_with_mask(x[0], y[0,:,:,0])
    break
# Out:
# (256, 256)

# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, UpSampling2D, Conv2D, MaxPooling2D, Activation


base_model = VGG16(weights='imagenet', input_shape=(256,256,3), include_top=False)


base_out = base_model.output


up = UpSampling2D(32, interpolation='bilinear')(base_out)
conv = Conv2D(1, (1, 1))(up)
conv = Activation('sigmoid')(conv)

model = Model(input=base_model.input, output=conv)
# Out:
# C:\Users\gendalf\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`

# %%
best_w = keras.callbacks.ModelCheckpoint('fcn_best.h5',
                                monitor='val_loss',
                                verbose=0,
                                save_best_only=True,
                                save_weights_only=True,
                                mode='auto',
                                period=1)

last_w = keras.callbacks.ModelCheckpoint('fcn_last.h5',
                                monitor='val_loss',
                                verbose=0,
                                save_best_only=False,
                                save_weights_only=True,
                                mode='auto',
                                period=1)


callbacks = [best_w, last_w]



adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)


model.compile(adam, 'binary_crossentropy')

# %%
batch_size = 16
model.fit_generator(keras_generator(dft, batch_size),
              steps_per_epoch=100,
              epochs=3,
              verbose=1,
              callbacks=callbacks,
              validation_data=keras_generator(dfv, batch_size),
              validation_steps=50,
              class_weight=None,
              max_queue_size=10,
              workers=1,
              use_multiprocessing=False,
              shuffle=True,
              initial_epoch=0)
# Out:
# Epoch 1/3
#   1/100 [..............................] - ETA: 8:07:24 - loss: 0.6918
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-222-ea90bf1dec1d>", line 14, in <module>
#     initial_epoch=0)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\keras\legacy\interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\keras\engine\training.py", line 1658, in fit_generator
#     initial_epoch=initial_epoch)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\keras\engine\training_generator.py", line 215, in fit_generator
#     class_weight=class_weight)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\keras\engine\training.py", line 1449, in train_on_batch
#     outputs = self.train_function(ins)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py", line 2979, in __call__
#     return self._call(inputs)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py", line 2937, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1458, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\gendalf\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\gendalf\Anaconda3\lib\inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\gendalf\Anaconda3\lib\inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\gendalf\Anaconda3\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\gendalf\Anaconda3\lib\inspect.py", line 734, in getmodule
#     f = module.__file__
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %% [markdown]
# Теперь восстановим маску:

# %%
decoded_mask = decode_rle(rle_mask)
show_img_with_mask(img, decoded_mask)

# %% [markdown]
# ---

# %%
# Out:
# Requirement already up-to-date: segmentation-models in c:\users\gendalf\appdata\roaming\python\python36\site-packages (1.0.0b1)

# %%
# Out:
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44924928/44920640 [==============================] - 38s 1us/step
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.

# %%
# Out:
# WARNING:tensorflow:From C:\Users\gendalf\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-ae6f4e7584b5> in <module>
#      22 # check shapes for errors
#      23 #print(train_dataloader[0][0].shape)
# ---> 24 assert train_dataloader[0][0].shape == (BATCH_SIZE, 320, 320, 3)
#      25 assert train_dataloader[0][1].shape == (BATCH_SIZE, 320, 320, n_classes)
#      26
#
# <ipython-input-6-495d2e149105> in __getitem__(self, i)
#      23         data = []
#      24         for j in range(start, stop):
# ---> 25             data.append(self.dataset[j])
#      26
#      27         # transpose list of lists
#
# <ipython-input-3-dcfc78fb3336> in __getitem__(self, i)
#      58         # apply preprocessing
#      59         if self.preprocessing:
# ---> 60             sample = self.preprocessing(image=image, mask=mask)
#      61             image, mask = sample['image'], sample['mask']
#      62
#
# ~\AppData\Roaming\Python\Python36\site-packages\albumentations\core\composition.py in __call__(self, force_apply, **data)
#     156                     p.preprocess(data)
#     157
# --> 158             data = t(force_apply=force_apply, **data)
#     159
#     160             if dual_start_end is not None and idx == dual_start_end[1]:
#
# ~\AppData\Roaming\Python\Python36\site-packages\albumentations\core\transforms_interface.py in __call__(self, force_apply, **kwargs)
#      63                     target_function = self._get_target_function(key)
#      64                     target_dependencies = {k: kwargs[k] for k in self.target_dependence.get(key, [])}
# ---> 65                     res[key] = target_function(arg, **dict(params, **target_dependencies))
#      66                 else:
#      67                     res[key] = None
#
# ~\AppData\Roaming\Python\Python36\site-packages\albumentations\augmentations\transforms.py in apply(self, img, **params)
#    2252     def apply(self, img, **params):
#    2253         fn = self.custom_apply_fns['image']
# -> 2254         return fn(img, **params)
#    2255
#    2256     def apply_to_mask(self, mask, **params):
#
# TypeError: <lambda>() got an unexpected keyword argument 'cols'

# %%
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-64-bad6d81bf722> in <module>
#      14     y_train_dir,
#      15 )
# ---> 16 image, mask = train_dataset[5]
#      17
#      18 train_dataset.masks_fps
#
# <ipython-input-63-0ab49fd56d1d> in __getitem__(self, i)
#      44         image = cv2.imread(self.images_fps[i])
#      45         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# ---> 46         mask = cv2.imread(self.masks_fps[i], 0)
#      47
#      48         # extract certain classes from mask (e.g. cars)
#
# SystemError: <built-in function imread> returned NULL without setting an error

# %% [markdown]
# # Результаты

# %% [markdown]
# Пример файла для изображений из `data/valid`:
# _Каждую предсказанную маску для изображения из `valid` необходимо закодировать и записать в показанный ниже файл, который служит примером, именно в таком виде нужно будет представить результат Вашего лучшего решения на данных из `valid`._

# %%
pred = pd.read_csv("C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/pred_valid_template.csv")
pred.head()
# Out:
#      id                                           rle_mask
# 0  1315  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 1  1316  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 2  1317  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 3  1318  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...
# 4  1319  9706 7 9939 15 9974 8 10174 20 10214 13 10412 ...

# %% [markdown]
# Для данных из `test` требуется создать html страницу + картинки для нее.
# Это можно сделать с помощью функции `get_html`, как показано ниже.

# %%
listd1=os.listdir("C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid")
pat1="C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid"
paths_to_imgs = sorted([(f"{pat1}/{x}") for x in listd1])
listd2=os.listdir("C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid_mask")
pat2="C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid_mask"
path=sorted([(f"{pat2}/{x}") for x in listd2])
pred_masks = [np.array(Image.open(path)) for path in path]
print(paths_to_imgs)
_ = get_html(paths_to_imgs, pred_masks, path_to_save="C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/results/example")
# Out:
# ['C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1315.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1316.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1317.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1318.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1319.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1320.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1321.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1322.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1323.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1324.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1325.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1326.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1327.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1328.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1329.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1330.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1331.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1332.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1333.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1334.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1335.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1336.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1337.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1338.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1339.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1340.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1341.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1342.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1343.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1344.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1345.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1346.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1347.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1348.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1349.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1350.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1351.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1352.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1353.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1354.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1355.jpg', 'C:/Users/gendalf/Documents/GitHub/InternshipTestTask/human_segmentation/data/valid/1356.jpg', 'C:/Users ...

# %% [markdown]
# В папке `results` создался файл `example.html` и папка `examples` с используемыми картинками.
